# %%
import torch
import train_sb3 as train
import matplotlib.pyplot as plt
import numpy as np

# %%
# 从环境加载数据
rl_experiment_name = 'sa_stack_sac_bess_fe_20250320-165457'
checkpoint_path_dict = train.checkpoint_path(rl_experiment_name, 0, 0)
raw_train_env, raw_eval_env = train.load_train_eval_env_for_data(checkpoint_path_dict)

# 设备检测
device = torch.device(
    "cuda" if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using device: {device}")
# Out:
# Make env: mode: train, whole_days: 122, train_days: 106, val_days: 16, test_days: 16
# Make env: mode: val, whole_days: 122, train_days: 106, val_days: 16, test_days: 16
# Using device: mps

# %%
losses = np.load('./checkpoint/base_load_pre/20250321-002659/losses.npz', allow_pickle=True)
plt.plot(losses['train_losses'], label='train')
plt.plot(losses['eval_losses'], label='eval')
plt.legend()
