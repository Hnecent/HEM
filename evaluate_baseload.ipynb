# %%
import torch
import train_sb3 as train
import matplotlib.pyplot as plt
import numpy as np

# %%
losses1 = np.load('./checkpoint/base_load_pre/20250328-163130/losses.npz', allow_pickle=True)
losses2 = np.load('./checkpoint/base_load_pre/20250328-144633/losses.npz', allow_pickle=True)
plt.plot(losses1['train_losses'], label='train')
plt.plot(losses1['eval_losses'], label='eval')
# plt.plot(losses2['train_losses'], label='train')
# plt.plot(losses2['eval_losses'], label='eval')

plt.legend()
